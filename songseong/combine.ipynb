# %%
import pandas as pd
import numpy as np

# %%
submit_mall1 = pd.read_csv("/root/workspace/songseong/dlinear_submit_0917_1_2.csv")
submit_mall2 = pd.read_csv("/root/workspace/songseong/patchtst_submit_0917_2_2.csv")

# %%
submit_mall1
# Out:
#                  ID  2023-04-25  2023-04-26  2023-04-27  2023-04-28  \
# 0      SAMPLE_00000           1           1           1           3
# 1      SAMPLE_00001           0           1           2           2
# 2      SAMPLE_00002           1           1           1           1
# 3      SAMPLE_00003           1           2           2           3
# 4      SAMPLE_00005           0           1          -1           4
# ...             ...         ...         ...         ...         ...
# 11221  SAMPLE_28889           0           0           1           1
# 11222  SAMPLE_28890         -27         -12          -7           2
# 11223  SAMPLE_28891          -1          -6          -1           7
# 11224  SAMPLE_28892           0           1           1           1
# 11225  SAMPLE_28893           1           0           1           1
#
#        2023-04-29  2023-04-30  2023-05-01  2023-05-02  2023-05-03  ...  \
# 0              -2           0           0          -1           0  ...
# ...

# %%
pd.read_csv("/root/workspace/songseong/patchtst_submit_0917_2.csv")
# Out:
#                  ID  2023-04-25  2023-04-26  2023-04-27  2023-04-28  \
# 0      SAMPLE_00004           6         161          18          52
# 1      SAMPLE_00008           1           0           0           0
# 2      SAMPLE_00009           0           0           0           0
# 3      SAMPLE_00010           3          -3           1          -3
# 4      SAMPLE_00012           0           0           0           0
# ...             ...         ...         ...         ...         ...
# 17663  SAMPLE_28845           0           0           0           0
# 17664  SAMPLE_28851           4           2           2           2
# 17665  SAMPLE_28852           0           0           0           0
# 17666  SAMPLE_28856          -2           1           4           4
# 17667  SAMPLE_28879           0           0           0           0
#
#        2023-04-29  2023-04-30  2023-05-01  2023-05-02  2023-05-03  ...  \
# 0              94         108         112          54          76  ...
# ...

# %%
submit_mall2
# Out:
#                  ID  2023-04-25  2023-04-26  2023-04-27  2023-04-28  \
# 0      SAMPLE_00004           6         161          18          52
# 1      SAMPLE_00008           1           0           0           0
# 2      SAMPLE_00009           0           0           0           0
# 3      SAMPLE_00010           3          -3           1          -3
# 4      SAMPLE_00012           0           0           0           0
# ...             ...         ...         ...         ...         ...
# 17663  SAMPLE_28845           0           0           0           0
# 17664  SAMPLE_28851           4           2           2           2
# 17665  SAMPLE_28852           0           0           0           0
# 17666  SAMPLE_28856          -2           1           4           4
# 17667  SAMPLE_28879           0           0           0           0
#
#        2023-04-29  2023-04-30  2023-05-01  2023-05-02  2023-05-03  ...  \
# 0              94         108         112          54          76  ...
# ...

# %%
submit = pd.concat([submit_mall1, submit_mall2], axis=0)

# %%
submit = submit.sort_values('ID')

# %%
submit.to_csv("/root/workspace/minkyung/submit/d_ku_submit_0917_2.csv", index=False)
